# %%
from statics import *
from constants import *

feature_extractor = FeatureExtractor(GROUND_TRUTH_FOLDER, segment_length_sec=5)
# Out:
# Extracting features from: 2024-09-05_20-46-25.mid
#   - Features saved for 2024-09-05_20-46-25.mid
# Extracting features from: 2024-09-04_21-51-59.mid
#   - Features saved for 2024-09-04_21-51-59.mid
# Extracting features from: 2024-02-17_00-12-50.mid
#   - Features saved for 2024-02-17_00-12-50.mid
# Extracting features from: 2024-09-03_00-44-45.mid
#   - Features saved for 2024-09-03_00-44-45.mid
# Extracting features from: 2024-02-15_21-40-43.mid
#   - Features saved for 2024-02-15_21-40-43.mid
# Extracting features from: 2024-09-04_22-06-40.mid
#   - Features saved for 2024-09-04_22-06-40.mid
# Extracting features from: 2024-09-02_23-22-31.mid
#   - Features saved for 2024-09-02_23-22-31.mid
# Extracting features from: 2024-03-13_11-32-42.mid
#   - Features saved for 2024-03-13_11-32-42.mid
# Extracting features from: 2024-03-12_15-43-01.mid
#   - Features saved for 2024-03-12_15-43-01.mid
# Extracting features from: 2024-09-05_20-51-00.mid
# ...

# %%
from statics import *
from constants import *

plotter = ScorePlotter(PREDICTED_FOLDER)

plotter.run_analysis_by_folder(save_plots = True)
