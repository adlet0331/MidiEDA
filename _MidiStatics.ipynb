# %%
from MidiStatics import MetadataAnalyzer
from constants import *

analyzer = MetadataAnalyzer(EVALUATION_FOLDER)

analyzer.run_analysis_by_folder(save_plots = True)
# Out:
# Scanning for 'evaluation.json' files in '/Users/simhyeongju/AVAPT/EDA/_transcribed_MIDI/OnsetsAndFrames_2.5secs'...
# ------------------------------------------------------------
# Processing file: 2024-09-02_18-42-47_16020Hz.wav
#   Analyzing 497 segments...
#   - Plot saved to: '/Users/simhyeongju/AVAPT/EDA/_transcribed_MIDI/OnsetsAndFrames_2.5secs/2024-09-02_18-42-47_16020Hz.wav/Precision_Distribution.png'
#   - Plot saved to: '/Users/simhyeongju/AVAPT/EDA/_transcribed_MIDI/OnsetsAndFrames_2.5secs/2024-09-02_18-42-47_16020Hz.wav/Recall_Distribution.png'
#   - Plot saved to: '/Users/simhyeongju/AVAPT/EDA/_transcribed_MIDI/OnsetsAndFrames_2.5secs/2024-09-02_18-42-47_16020Hz.wav/F1-Score_Distribution.png'
#   - Statistics saved to: '/Users/simhyeongju/AVAPT/EDA/_transcribed_MIDI/OnsetsAndFrames_2.5secs/2024-09-02_18-42-47_16020Hz.wav/statistics_metadata.json'
# ------------------------------------------------------------
# Processing file: 2024-09-02_18-25-31_16020Hz.wav
# ...
