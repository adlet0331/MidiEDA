# %%
from constants import *
from statics import FeatureExtractor

feature_extractor = FeatureExtractor(MIKROKOSMOS_MIDI_FOLDER, segment_length_sec=5)
# Out:
# Extracting features from: 49.mid
#   - Features saved for 49.mid
# Extracting features from: 75.mid
#   - Features saved for 75.mid
# Extracting features from: 61.mid
#   - Features saved for 61.mid
# Extracting features from: 148.mid
#   - Features saved for 148.mid
# Extracting features from: 149.mid
#   - Features saved for 149.mid
# Extracting features from: 60.mid
#   - Features saved for 60.mid
# Extracting features from: 74.mid
#   - Features saved for 74.mid
# Extracting features from: 48.mid
#   - Features saved for 48.mid
# Extracting features from: 62.mid
#   - Features saved for 62.mid
# Extracting features from: 76.mid
#   - Features saved for 76.mid
# Extracting features from: 89.mid
#   - Features saved for 89.mid
# Extracting features from: 88.mid
#   - Features saved for 88.mid
# Extracting features from: 77.mid
#   - Features saved for 77.mid
# Extracting features from: 63.mid
#   - Features saved for 63.mid
# Extracting features from: 67.mid
# ...
