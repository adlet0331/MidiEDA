# %%
from rubric_interpretability import *

features_name, label_features, label_scores = get_features_data(
    runs_name="runs-audio/p-est-250824-204844",
    cipi_cached_path="/Users/simhyeongju/AVAPT/EDA/_transcribed_MIDI/OnsetsAndFrames_2_5sec/features",
    cipi_label_path="/Users/simhyeongju/AVAPT/EDA/_transcribed_MIDI/OnsetsAndFrames_2_5sec/index.json"
)

# for i, scores in enumerate(label_scores):
#     print(f"Label {i + 1} scores: {scores}")
    
label_scores_sums = [(np.sum(scores, axis=1) + 14) / 2 for scores in label_scores]
width_list = []
width = 0
for i in range(9):
    print(np.min(label_scores_sums[i]), np.max(label_scores_sums[i]), np.mean(label_scores_sums[i]))
    width_list.append(np.max(label_scores_sums[i]) - width)
    width = np.max(label_scores_sums[i])
width_list[-1] = 14 - sum(width_list[:-1])
print(width_list)
create_segmented_bar(width_list)
# Out:
# /Users/simhyeongju/AVAPT/.venv/lib/python3.10/site-packages/pretty_midi/instrument.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       3 features_name, label_features, label_scores = get_features_data(runs_name="runs-audio/p-est-250824-204844")
#       5 # for i, scores in enumerate(label_scores):
#       6 #     print(f"Label {i + 1} scores: {scores}")
# ----> 8 label_scores_sums = [(np.sum(scores, axis=1) + 14) / 2 for scores in label_scores]
#       9 width_list = []
#      10 width = 0
#
# Cell In[1], line 8, in <listcomp>(.0)
# ...

# %%
from rubric_interpretability import *

features_name, label_features, label_scores = get_features_data()

mean_label_scores = [(np.mean(scores, axis=0) + 1) / 2 for scores in label_scores]
# print(*mean_label_scores, sep="\n")

create_descriptor_plot(features_name, mean_label_scores)
# Out:
# /Users/simhyeongju/AVAPT/.venv/lib/python3.10/site-packages/pretty_midi/instrument.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# 설명자 수: 14, 등급 수: 9

# %%
from rubric_interpretability import *

features_name, label_features, label_scores = get_features_data()

plot_descriptor_scores_vs_values(label_scores[0][0].reshape(-1), label_features[0][0].reshape(-1), features_name)
