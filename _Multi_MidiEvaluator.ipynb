# %%
from MultiMidiEvaluator import MultiMidiEvaluator
from constants import *

# 평가 클래스 인스턴스화
evaluator = MultiMidiEvaluator(
    predicted_midi_folder="/Users/simhyeongju/AVAPT/EDA/_transcribed_MIDI/OnsetsAndFrames_2_5sec",
    ground_truth_midi_folder=GROUND_TRUTH_FOLDER
)

evaluation_results = evaluator.evaluate_all()
# Out:
# ✅ MultiMidiEvaluator가 성공적으로 초기화되었습니다.
#
#  MIDI 전체 평가를 시작합니다 (offset_ratio=None)... 🎶
# [1/107] 파일 평가 중: 2024-09-02_18-42-47_16020Hz
#   - ❌ 예측 MIDI 파일이 비어 있습니다: /Users/simhyeongju/AVAPT/EDA/_transcribed_MIDI/OnsetsAndFrames_2_5sec/2024-09-02_18-42-47_16020Hz/141.mid. 이 파일을 건너뜁니다.
#   - ❌ 예측 MIDI 파일이 비어 있습니다: /Users/simhyeongju/AVAPT/EDA/_transcribed_MIDI/OnsetsAndFrames_2_5sec/2024-09-02_18-42-47_16020Hz/249.mid. 이 파일을 건너뜁니다.
#   - ✅ 완료. 평균 F1-Score: 0.9692
#   - 💾 결과가 다음 파일에 저장되었습니다: /Users/simhyeongju/AVAPT/EDA/_transcribed_MIDI/OnsetsAndFrames_2_5sec/2024-09-02_18-42-47_16020Hz/evaluation.json
# [2/107] 파일 평가 중: 2024-09-02_18-25-31_16020Hz
#   - ❌ 예측 MIDI 파일이 비어 있습니다: /Users/simhyeongju/AVAPT/EDA/_transcribed_MIDI/OnsetsAndFrames_2_5sec/2024-09-02_18-25-31_16020Hz/26.mid. 이 파일을 건너뜁니다.
#   - ✅ 완료. 평균 F1-Score: 0.9905
#   - 💾 결과가 다음 파일에 저장되었습니다: /Users/simhyeongju/AVAPT/EDA/_transcribed_MIDI/OnsetsAndFrames_2_5sec/2024-09-02_18-25-31_16020Hz/evaluation.json
# ...
